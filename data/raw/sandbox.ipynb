# %%
import polars as pl

# %%
lcl_df = pl.read_csv('CC_LCL-FullData.csv')
lcl_df.head()

# %%
goiener_df = pl.read_csv('GoiEner.csv')
goiener_df.head()

# %%
def getUniqueCount(df:pl.DataFrame, group_by:str):
    return df.group_by(group_by).len().sort('len', descending=True)

# %%
profiles = lcl_df['LCLid'].unique()

# %%
len(profiles)

# %%
goiener_df.describe()
