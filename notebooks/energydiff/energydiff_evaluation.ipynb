# %% [markdown]
# # Privacy evaluation
#
# This tutorial explains how to evaluate the privacy of synthetic smart meter data. This notebook is based on the EnergyDiff framework, trained on Low Carbon London dataset.
#
# - For more information on EnergyDiff's architecture, refer to the [EnergyDiff paper](https://arxiv.org/abs/2407.13538).
# - For more information on evaluation method, refer to the paper by Centre for Net Zero on [Defining 'Good': Evaluation Framework for Synthetic Smart Meter Data
# ](https://arxiv.org/abs/2407.11785).
#
# ### Pre-requisites
#
# 1. If you haven't already, please download LCL dataset from [data.london.gov.uk](https://data.london.gov.uk/dataset/smartmeter-energy-use-data-in-london-households).
# 2. If you haven't already, you need to first train a model (refer to the `energydiff_tutorial.ipynb` notebook).

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

import logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # 💿 Loading LCL Data

# %%
from pathlib import Path
from opensynth.data_modules.lcl_data_module import LCLDataModule
import pytorch_lightning as pl

import matplotlib.pyplot as plt

data_path = Path("../../data/processed/historical/train/lcl_data.csv")
stats_path = Path("../../data/processed/historical/train/mean_std.csv")
outlier_path = Path("../../data/processed/historical/train/outliers.csv")

# Original training data with no outliers
dm = LCLDataModule(data_path=data_path, stats_path=stats_path, batch_size=5000, n_samples=20000)
dm.setup()

# %%
# Training data with implausible outliers injected for privacy attacks
dm_with_outliers = LCLDataModule(data_path=data_path, stats_path=stats_path, batch_size=5000, n_samples=20000, outlier_path=outlier_path)
dm_with_outliers.setup()

# %%
# Holdout data
holdout_path = Path("../../data/processed/historical/holdout/lcl_data.csv")
dm_holdout = LCLDataModule(data_path=holdout_path, stats_path=stats_path, batch_size=5000, n_samples=20000)
dm_holdout.setup()

# %% [markdown]
# # 🤖 Load Pretrained EnergyDiff model

# %%
from opensynth.models.energydiff.diffusion import PLDiffusion1D
import numpy as np
import torch

# %%
df_model = PLDiffusion1D.load_from_checkpoint("lightning_logs/"+
                                              "version_3/"+
                                              "checkpoints/"+
                                              "epoch=99-step=1900.ckpt")

# %%
df_kwh = torch.load("lightning_logs/version_3"
                        +"/samples/dpm_kwh_calib.pt")
# pay attention to the map location

# %% [markdown]
# # 1️⃣ Reconstruction Attack

# %% [markdown]
# As described in the Defining good paper, the reconstruction attack involves:
#
# 1. Train the generative model with implausible outliers injected (100)
# 2. Generate a random sample of data from the injected outliers (10000)
# 3. Calculate the pairwise euclidean distances of each injected outlier with every sample in the batch of randomly generated data.
# 4. Aggregate the results to retrieve the nearest generated sample for each outlier, and express the distance as a ratio of the norm of the outlier's vector.
# 5. Visualise results in a cumulative distribution function.

# %% [markdown]
# ### 🏭 Create Reconstruction Attack Dataset

# %%
from opensynth.evaluation.privacy import reconstruction_attack

# n_samples == batch_size
real_kwh = next(iter(dm_with_outliers.train_dataloader()))['kwh']
real_kwh = dm_with_outliers.reconstruct_kwh(real_kwh)
outlier_kwh = next(iter(dm_with_outliers.outlier_dataloader()))['kwh']
outlier_kwh = dm_with_outliers.reconstruct_kwh(outlier_kwh)

df_attack_dataset = reconstruction_attack.ReconstructionAttackDataset(
    synthetic_samples=df_kwh,
    real_samples=real_kwh,
    outlier_samples=outlier_kwh
)

# %% [markdown]
# ### 🧮 Calculating pair-wise euclidean distances

# %%
df_distance_norm = reconstruction_attack.calculate_distance_norm(
    real = df_attack_dataset.outlier_samples,
    fake = df_attack_dataset.synthetic_samples,
    group_min=True
)

# %% [markdown]
# ### 📈 Plotting cumulative distribution function

# %% [markdown]
# In the defining good paper, it is recommended that threshold ratio be set to 0.3. This is analogous to saying that for a outlier profile with daily total consumption of 30kwh, a generated profile with total consumption within 30% (21±9kwh) is sufficient to render that outlier compromised.

# %%
import pandas as pd
import seaborn as sns


df_distance_norm["model"] = "energydiff"

df_reconstruction_attack_results = pd.concat([
    df_distance_norm,
]).reset_index(drop=True)

sns.ecdfplot(data=df_reconstruction_attack_results, x="ratio", hue="model")
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# # 2️⃣ Membership Inference Attacks

# %% [markdown]
# **_note: EnergyDiff in its original design is not tailored for dealing with privacy attacks. However, it is possible to evaluate the privacy of synthetic data using the membership inference attack._**
#
# As described in the Defining good paper, the membership inference attack involves:
#
# 1. Train a discriminator that attempts to distinguish between synthetically generated data and the holdout set (real data but unseen during training of the generative model.)
# 2. Create an 'attack dataset' that comprises of 1) Seen outliers during the training of the generative model 2) Unseen outliers but belonging to the same distribution to the seen outliers, and 3) Unseen outliers but belonging to a different distribution. A random guess would yield a precision of 33%.
# 3. Use the trained discriminative model to predict on the attack dataset and report on the precision, and check that it is no better than random guess.

# %% [markdown]
# ### 🏭 Create Membership Inference Attack Dataset

# %%
from opensynth.evaluation.privacy import membership_inference_attack as mia
import pytorch_lightning as pl

# n_samples == batch_size
dm_mia_df = mia.MembershipInferenceDataModule(
    model=df_model,
    dm_train=dm_with_outliers,
    dm_holdout=dm_holdout,
    batch_size=5000,
    synthetic_samples=df_kwh
)
dm_mia_df.setup("")

# %% [markdown]
# ### 🤖 Train discriminator models

# %% [markdown]
# #### EnergyDiff

# %%
mia_model_df = mia.MembershipInferenceModel(learning_rate=0.02,
                                            input_size=48)
train_dl = dm_mia_df.train_dataloader()
eval_dl = dm_mia_df.eval_dataloader()
trainer = pl.Trainer(max_epochs=100, accelerator="auto", strategy="auto")
trainer.fit(mia_model_df, 
            train_dataloaders=train_dl,
            val_dataloaders=eval_dl)
# Out:
# Using default `ModelCheckpoint`. Consider installing `litmodels` package to enable `LitModelCheckpoint` for automatic upload to the Lightning model registry.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /Users/hajalibayram/phd/dev/OpenSynth/.venv/lib/python3.13/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#
#   | Name    | Type                      | Params | Mode
# --------------------------------------------------------------
# 0 | loss_fn | BCEWithLogitsLoss         | 0      | train
# 1 | model   | MembershipInferenceModule | 2.2 K  | train
# --------------------------------------------------------------
# 2.2 K     Trainable params
# 0         Non-trainable params
# 2.2 K     Total params
# 0.009     Total estimated model params size (MB)
# 11        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/hajalibayram/phd/dev/OpenSynth/.venv/lib/python3.13/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:425: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/hajalibayram/phd/dev/OpenSynth/.venv/lib/python3.13/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:425: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=9` in the `DataLoader` to improve performance.
# /Users/hajalibayram/phd/dev/OpenSynth/.venv/lib/python3.13/site-packages/pytorch_lightning/loops/fit_loop.py:310: The number of training batches (6) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0: 100%|██████████| 6/6 [00:00<00:00,  8.45it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 137.65it/s]
# Epoch 1: 100%|██████████| 6/6 [00:00<00:00, 19.98it/s, v_num=4, Eval BCE Loss=0.693, Eval Accuracy=0.498, Train BCE Loss=0.695, Train Accuracy=0.501]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 160.80it/s]
# Epoch 2: 100%|██████████| 6/6 [00:00<00:00, 51.82it/s, v_num=4, Eval BCE Loss=0.693, Eval Accuracy=0.513, Train BCE Loss=0.693, Train Accuracy=0.515]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 163.53it/s]
# Epoch 3: 100%|██████████| 6/6 [00:00<00:00, 49.91it/s, v_num=4, Eval BCE Loss=0.692, Eval Accuracy=0.520, Train BCE Loss=0.692, Train Accuracy=0.516]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 154.94it/s]
# Epoch 4: 100%|██████████| 6/6 [00:00<00:00, 51.19it/s, v_num=4, Eval BCE Loss=0.690, Eval Accuracy=0.537, Train BCE Loss=0.691, Train Accuracy=0.530]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.94it/s]
# Epoch 5: 100%|██████████| 6/6 [00:00<00:00, 30.29it/s, v_num=4, Eval BCE Loss=0.689, Eval Accuracy=0.537, Train BCE Loss=0.690, Train Accuracy=0.536]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 121.37it/s]
# Epoch 6: 100%|██████████| 6/6 [00:00<00:00, 47.69it/s, v_num=4, Eval BCE Loss=0.687, Eval Accuracy=0.542, Train BCE Loss=0.688, Train Accuracy=0.539]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 146.95it/s]
# Epoch 7: 100%|██████████| 6/6 [00:00<00:00, 51.29it/s, v_num=4, Eval BCE Loss=0.684, Eval Accuracy=0.555, Train BCE Loss=0.686, Train Accuracy=0.544]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 155.64it/s]
# Epoch 8: 100%|██████████| 6/6 [00:00<00:00, 22.81it/s, v_num=4, Eval BCE Loss=0.682, Eval Accuracy=0.551, Train BCE Loss=0.685, Train Accuracy=0.544]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 174.07it/s]
# Epoch 9: 100%|██████████| 6/6 [00:00<00:00, 49.10it/s, v_num=4, Eval BCE Loss=0.683, Eval Accuracy=0.555, Train BCE Loss=0.683, Train Accuracy=0.550]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.94it/s]
# Epoch 10: 100%|██████████| 6/6 [00:00<00:00, 48.96it/s, v_num=4, Eval BCE Loss=0.683, Eval Accuracy=0.551, Train BCE Loss=0.682, Train Accuracy=0.554]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 158.47it/s]
# Epoch 11: 100%|██████████| 6/6 [00:00<00:00, 45.66it/s, v_num=4, Eval BCE Loss=0.683, Eval Accuracy=0.559, Train BCE Loss=0.681, Train Accuracy=0.556]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 159.34it/s]
# Epoch 12: 100%|██████████| 6/6 [00:00<00:00, 48.89it/s, v_num=4, Eval BCE Loss=0.684, Eval Accuracy=0.553, Train BCE Loss=0.681, Train Accuracy=0.554]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 155.47it/s]
# Epoch 13: 100%|██████████| 6/6 [00:00<00:00, 47.92it/s, v_num=4, Eval BCE Loss=0.687, Eval Accuracy=0.551, Train BCE Loss=0.680, Train Accuracy=0.558]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 170.88it/s]
# Epoch 14: 100%|██████████| 6/6 [00:00<00:00, 23.06it/s, v_num=4, Eval BCE Loss=0.679, Eval Accuracy=0.560, Train BCE Loss=0.679, Train Accuracy=0.559]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 169.78it/s]
# Epoch 15: 100%|██████████| 6/6 [00:00<00:00, 47.49it/s, v_num=4, Eval BCE Loss=0.678, Eval Accuracy=0.566, Train BCE Loss=0.678, Train Accuracy=0.565]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 167.99it/s]
# Epoch 16: 100%|██████████| 6/6 [00:00<00:00, 48.23it/s, v_num=4, Eval BCE Loss=0.679, Eval Accuracy=0.562, Train BCE Loss=0.677, Train Accuracy=0.559]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 153.45it/s]
# Epoch 17: 100%|██████████| 6/6 [00:00<00:00, 48.39it/s, v_num=4, Eval BCE Loss=0.687, Eval Accuracy=0.553, Train BCE Loss=0.676, Train Accuracy=0.567]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 157.08it/s]
# Epoch 18: 100%|██████████| 6/6 [00:00<00:00, 49.41it/s, v_num=4, Eval BCE Loss=0.682, Eval Accuracy=0.559, Train BCE Loss=0.677, Train Accuracy=0.562]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 178.44it/s]
# Epoch 19: 100%|██████████| 6/6 [00:00<00:00, 48.66it/s, v_num=4, Eval BCE Loss=0.682, Eval Accuracy=0.564, Train BCE Loss=0.676, Train Accuracy=0.563]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 147.34it/s]
# Epoch 20: 100%|██████████| 6/6 [00:00<00:00, 23.32it/s, v_num=4, Eval BCE Loss=0.686, Eval Accuracy=0.557, Train BCE Loss=0.677, Train Accuracy=0.564]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 165.95it/s]
# Epoch 21: 100%|██████████| 6/6 [00:00<00:00, 48.55it/s, v_num=4, Eval BCE Loss=0.685, Eval Accuracy=0.557, Train BCE Loss=0.676, Train Accuracy=0.564]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 162.26it/s]
# Epoch 22: 100%|██████████| 6/6 [00:00<00:00, 49.10it/s, v_num=4, Eval BCE Loss=0.682, Eval Accuracy=0.557, Train BCE Loss=0.676, Train Accuracy=0.563]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 85.88it/s]
# Epoch 23: 100%|██████████| 6/6 [00:00<00:00, 48.92it/s, v_num=4, Eval BCE Loss=0.679, Eval Accuracy=0.568, Train BCE Loss=0.674, Train Accuracy=0.569]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 159.10it/s]
# Epoch 24: 100%|██████████| 6/6 [00:00<00:00, 50.19it/s, v_num=4, Eval BCE Loss=0.681, Eval Accuracy=0.556, Train BCE Loss=0.674, Train Accuracy=0.568]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.50it/s]
# Epoch 25: 100%|██████████| 6/6 [00:00<00:00, 49.70it/s, v_num=4, Eval BCE Loss=0.680, Eval Accuracy=0.557, Train BCE Loss=0.673, Train Accuracy=0.566]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 175.87it/s]
# Epoch 26: 100%|██████████| 6/6 [00:00<00:00, 50.33it/s, v_num=4, Eval BCE Loss=0.681, Eval Accuracy=0.552, Train BCE Loss=0.673, Train Accuracy=0.567]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.56it/s]
# Epoch 27: 100%|██████████| 6/6 [00:00<00:00, 22.65it/s, v_num=4, Eval BCE Loss=0.680, Eval Accuracy=0.556, Train BCE Loss=0.671, Train Accuracy=0.569]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 149.41it/s]
# Epoch 28: 100%|██████████| 6/6 [00:00<00:00, 49.88it/s, v_num=4, Eval BCE Loss=0.682, Eval Accuracy=0.560, Train BCE Loss=0.672, Train Accuracy=0.576]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 178.03it/s]
# Epoch 29: 100%|██████████| 6/6 [00:00<00:00, 49.64it/s, v_num=4, Eval BCE Loss=0.681, Eval Accuracy=0.554, Train BCE Loss=0.672, Train Accuracy=0.570]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 161.16it/s]
# Epoch 30: 100%|██████████| 6/6 [00:00<00:00, 48.98it/s, v_num=4, Eval BCE Loss=0.682, Eval Accuracy=0.543, Train BCE Loss=0.671, Train Accuracy=0.573]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 177.46it/s]
# Epoch 31: 100%|██████████| 6/6 [00:00<00:00, 49.86it/s, v_num=4, Eval BCE Loss=0.678, Eval Accuracy=0.559, Train BCE Loss=0.671, Train Accuracy=0.574]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 159.97it/s]
# Epoch 32: 100%|██████████| 6/6 [00:00<00:00, 48.83it/s, v_num=4, Eval BCE Loss=0.683, Eval Accuracy=0.556, Train BCE Loss=0.671, Train Accuracy=0.574]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 149.39it/s]
# Epoch 33: 100%|██████████| 6/6 [00:00<00:00, 23.59it/s, v_num=4, Eval BCE Loss=0.682, Eval Accuracy=0.556, Train BCE Loss=0.671, Train Accuracy=0.576]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 151.50it/s]
# Epoch 34: 100%|██████████| 6/6 [00:00<00:00, 28.20it/s, v_num=4, Eval BCE Loss=0.682, Eval Accuracy=0.556, Train BCE Loss=0.670, Train Accuracy=0.574]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 114.39it/s]
# Epoch 35: 100%|██████████| 6/6 [00:00<00:00, 42.86it/s, v_num=4, Eval BCE Loss=0.680, Eval Accuracy=0.559, Train BCE Loss=0.669, Train Accuracy=0.576]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 128.47it/s]
# Epoch 36: 100%|██████████| 6/6 [00:00<00:00, 38.81it/s, v_num=4, Eval BCE Loss=0.681, Eval Accuracy=0.553, Train BCE Loss=0.669, Train Accuracy=0.580]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 138.85it/s]
# Epoch 37: 100%|██████████| 6/6 [00:00<00:00, 22.69it/s, v_num=4, Eval BCE Loss=0.685, Eval Accuracy=0.553, Train BCE Loss=0.669, Train Accuracy=0.579]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 71.73it/s]
# Epoch 38: 100%|██████████| 6/6 [00:00<00:00, 36.94it/s, v_num=4, Eval BCE Loss=0.690, Eval Accuracy=0.549, Train BCE Loss=0.669, Train Accuracy=0.576]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 147.78it/s]
# Epoch 39: 100%|██████████| 6/6 [00:00<00:00, 48.12it/s, v_num=4, Eval BCE Loss=0.680, Eval Accuracy=0.562, Train BCE Loss=0.670, Train Accuracy=0.577]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 136.16it/s]
# Epoch 40: 100%|██████████| 6/6 [00:00<00:00, 47.81it/s, v_num=4, Eval BCE Loss=0.688, Eval Accuracy=0.554, Train BCE Loss=0.668, Train Accuracy=0.578]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 145.00it/s]
# Epoch 41: 100%|██████████| 6/6 [00:00<00:00, 48.00it/s, v_num=4, Eval BCE Loss=0.683, Eval Accuracy=0.552, Train BCE Loss=0.669, Train Accuracy=0.576]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 158.73it/s]
# Epoch 42: 100%|██████████| 6/6 [00:00<00:00, 48.87it/s, v_num=4, Eval BCE Loss=0.694, Eval Accuracy=0.542, Train BCE Loss=0.668, Train Accuracy=0.581]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 159.38it/s]
# Epoch 43: 100%|██████████| 6/6 [00:00<00:00, 48.80it/s, v_num=4, Eval BCE Loss=0.688, Eval Accuracy=0.551, Train BCE Loss=0.667, Train Accuracy=0.575]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 149.61it/s]
# Epoch 44: 100%|██████████| 6/6 [00:00<00:00, 49.34it/s, v_num=4, Eval BCE Loss=0.683, Eval Accuracy=0.555, Train BCE Loss=0.668, Train Accuracy=0.576]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 175.71it/s]
# Epoch 45: 100%|██████████| 6/6 [00:00<00:00, 46.03it/s, v_num=4, Eval BCE Loss=0.690, Eval Accuracy=0.553, Train BCE Loss=0.666, Train Accuracy=0.581]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 158.43it/s]
# Epoch 46: 100%|██████████| 6/6 [00:00<00:00, 50.70it/s, v_num=4, Eval BCE Loss=0.694, Eval Accuracy=0.545, Train BCE Loss=0.667, Train Accuracy=0.578]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 149.52it/s]
# Epoch 47: 100%|██████████| 6/6 [00:00<00:00, 47.59it/s, v_num=4, Eval BCE Loss=0.692, Eval Accuracy=0.558, Train BCE Loss=0.667, Train Accuracy=0.577]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 169.26it/s]
# Epoch 48: 100%|██████████| 6/6 [00:00<00:00, 50.16it/s, v_num=4, Eval BCE Loss=0.690, Eval Accuracy=0.553, Train BCE Loss=0.669, Train Accuracy=0.575]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 174.49it/s]
# Epoch 49: 100%|██████████| 6/6 [00:00<00:00, 47.73it/s, v_num=4, Eval BCE Loss=0.688, Eval Accuracy=0.558, Train BCE Loss=0.666, Train Accuracy=0.578]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 173.64it/s]
# Epoch 50: 100%|██████████| 6/6 [00:00<00:00, 49.97it/s, v_num=4, Eval BCE Loss=0.690, Eval Accuracy=0.556, Train BCE Loss=0.666, Train Accuracy=0.576]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 168.92it/s]
# Epoch 51: 100%|██████████| 6/6 [00:00<00:00, 50.29it/s, v_num=4, Eval BCE Loss=0.702, Eval Accuracy=0.542, Train BCE Loss=0.666, Train Accuracy=0.576]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.92it/s]
# Epoch 52: 100%|██████████| 6/6 [00:00<00:00, 50.57it/s, v_num=4, Eval BCE Loss=0.693, Eval Accuracy=0.552, Train BCE Loss=0.665, Train Accuracy=0.579]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 165.48it/s]
# Epoch 53: 100%|██████████| 6/6 [00:00<00:00, 24.41it/s, v_num=4, Eval BCE Loss=0.694, Eval Accuracy=0.557, Train BCE Loss=0.665, Train Accuracy=0.578]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 167.16it/s]
# Epoch 54: 100%|██████████| 6/6 [00:00<00:00, 50.21it/s, v_num=4, Eval BCE Loss=0.689, Eval Accuracy=0.557, Train BCE Loss=0.665, Train Accuracy=0.581]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 167.65it/s]
# Epoch 55: 100%|██████████| 6/6 [00:00<00:00, 51.80it/s, v_num=4, Eval BCE Loss=0.690, Eval Accuracy=0.544, Train BCE Loss=0.666, Train Accuracy=0.580]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 169.32it/s]
# Epoch 56: 100%|██████████| 6/6 [00:00<00:00, 52.03it/s, v_num=4, Eval BCE Loss=0.702, Eval Accuracy=0.543, Train BCE Loss=0.664, Train Accuracy=0.580]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 165.01it/s]
# Epoch 57: 100%|██████████| 6/6 [00:00<00:00, 50.89it/s, v_num=4, Eval BCE Loss=0.690, Eval Accuracy=0.551, Train BCE Loss=0.665, Train Accuracy=0.581]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 161.57it/s]
# Epoch 58: 100%|██████████| 6/6 [00:00<00:00, 51.59it/s, v_num=4, Eval BCE Loss=0.698, Eval Accuracy=0.552, Train BCE Loss=0.665, Train Accuracy=0.583]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.17it/s]
# Epoch 59: 100%|██████████| 6/6 [00:00<00:00, 23.00it/s, v_num=4, Eval BCE Loss=0.688, Eval Accuracy=0.555, Train BCE Loss=0.664, Train Accuracy=0.581]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 159.08it/s]
# Epoch 60: 100%|██████████| 6/6 [00:00<00:00, 49.52it/s, v_num=4, Eval BCE Loss=0.699, Eval Accuracy=0.539, Train BCE Loss=0.664, Train Accuracy=0.584]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 175.11it/s]
# Epoch 61: 100%|██████████| 6/6 [00:00<00:00, 50.50it/s, v_num=4, Eval BCE Loss=0.701, Eval Accuracy=0.545, Train BCE Loss=0.663, Train Accuracy=0.585]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 180.05it/s]
# Epoch 62: 100%|██████████| 6/6 [00:00<00:00, 48.96it/s, v_num=4, Eval BCE Loss=0.707, Eval Accuracy=0.541, Train BCE Loss=0.664, Train Accuracy=0.582]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.39it/s]
# Epoch 63: 100%|██████████| 6/6 [00:00<00:00, 49.26it/s, v_num=4, Eval BCE Loss=0.695, Eval Accuracy=0.549, Train BCE Loss=0.664, Train Accuracy=0.585]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.67it/s]
# Epoch 64: 100%|██████████| 6/6 [00:00<00:00, 50.49it/s, v_num=4, Eval BCE Loss=0.701, Eval Accuracy=0.545, Train BCE Loss=0.664, Train Accuracy=0.583]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 173.55it/s]
# Epoch 65: 100%|██████████| 6/6 [00:00<00:00, 51.05it/s, v_num=4, Eval BCE Loss=0.705, Eval Accuracy=0.543, Train BCE Loss=0.663, Train Accuracy=0.586]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 170.09it/s]
# Epoch 66: 100%|██████████| 6/6 [00:00<00:00, 24.17it/s, v_num=4, Eval BCE Loss=0.695, Eval Accuracy=0.553, Train BCE Loss=0.664, Train Accuracy=0.587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 168.89it/s]
# Epoch 67: 100%|██████████| 6/6 [00:00<00:00, 50.50it/s, v_num=4, Eval BCE Loss=0.702, Eval Accuracy=0.551, Train BCE Loss=0.663, Train Accuracy=0.582]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 174.89it/s]
# Epoch 68: 100%|██████████| 6/6 [00:00<00:00, 51.66it/s, v_num=4, Eval BCE Loss=0.698, Eval Accuracy=0.549, Train BCE Loss=0.662, Train Accuracy=0.584]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 173.43it/s]
# Epoch 69: 100%|██████████| 6/6 [00:00<00:00, 50.72it/s, v_num=4, Eval BCE Loss=0.710, Eval Accuracy=0.544, Train BCE Loss=0.662, Train Accuracy=0.587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 165.89it/s]
# Epoch 70: 100%|██████████| 6/6 [00:00<00:00, 49.98it/s, v_num=4, Eval BCE Loss=0.704, Eval Accuracy=0.544, Train BCE Loss=0.661, Train Accuracy=0.588]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.06it/s]
# Epoch 71: 100%|██████████| 6/6 [00:00<00:00, 47.39it/s, v_num=4, Eval BCE Loss=0.704, Eval Accuracy=0.544, Train BCE Loss=0.659, Train Accuracy=0.587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 158.13it/s]
# Epoch 72: 100%|██████████| 6/6 [00:00<00:00, 22.72it/s, v_num=4, Eval BCE Loss=0.701, Eval Accuracy=0.552, Train BCE Loss=0.663, Train Accuracy=0.586]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 138.03it/s]
# Epoch 73: 100%|██████████| 6/6 [00:00<00:00, 47.55it/s, v_num=4, Eval BCE Loss=0.701, Eval Accuracy=0.549, Train BCE Loss=0.663, Train Accuracy=0.587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.95it/s]
# Epoch 74: 100%|██████████| 6/6 [00:00<00:00, 49.55it/s, v_num=4, Eval BCE Loss=0.702, Eval Accuracy=0.547, Train BCE Loss=0.662, Train Accuracy=0.591]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 152.68it/s]
# Epoch 75: 100%|██████████| 6/6 [00:00<00:00, 49.09it/s, v_num=4, Eval BCE Loss=0.707, Eval Accuracy=0.543, Train BCE Loss=0.662, Train Accuracy=0.586]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 156.13it/s]
# Epoch 76: 100%|██████████| 6/6 [00:00<00:00, 49.57it/s, v_num=4, Eval BCE Loss=0.704, Eval Accuracy=0.544, Train BCE Loss=0.662, Train Accuracy=0.583]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 169.78it/s]
# Epoch 77: 100%|██████████| 6/6 [00:00<00:00, 49.91it/s, v_num=4, Eval BCE Loss=0.699, Eval Accuracy=0.552, Train BCE Loss=0.661, Train Accuracy=0.586]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 173.71it/s]
# Epoch 78: 100%|██████████| 6/6 [00:00<00:00, 24.09it/s, v_num=4, Eval BCE Loss=0.702, Eval Accuracy=0.545, Train BCE Loss=0.664, Train Accuracy=0.584]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 177.01it/s]
# Epoch 79: 100%|██████████| 6/6 [00:00<00:00, 49.44it/s, v_num=4, Eval BCE Loss=0.707, Eval Accuracy=0.548, Train BCE Loss=0.663, Train Accuracy=0.587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 161.39it/s]
# Epoch 80: 100%|██████████| 6/6 [00:00<00:00, 50.45it/s, v_num=4, Eval BCE Loss=0.705, Eval Accuracy=0.549, Train BCE Loss=0.661, Train Accuracy=0.587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 182.96it/s]
# Epoch 81: 100%|██████████| 6/6 [00:00<00:00, 51.92it/s, v_num=4, Eval BCE Loss=0.713, Eval Accuracy=0.536, Train BCE Loss=0.662, Train Accuracy=0.588]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 177.65it/s]
# Epoch 82: 100%|██████████| 6/6 [00:00<00:00, 48.62it/s, v_num=4, Eval BCE Loss=0.714, Eval Accuracy=0.542, Train BCE Loss=0.661, Train Accuracy=0.586]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.07it/s]
# Epoch 83: 100%|██████████| 6/6 [00:00<00:00, 50.12it/s, v_num=4, Eval BCE Loss=0.707, Eval Accuracy=0.552, Train BCE Loss=0.661, Train Accuracy=0.584]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 160.41it/s]
# Epoch 84: 100%|██████████| 6/6 [00:00<00:00, 48.88it/s, v_num=4, Eval BCE Loss=0.719, Eval Accuracy=0.538, Train BCE Loss=0.660, Train Accuracy=0.587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 167.39it/s]
# Epoch 85: 100%|██████████| 6/6 [00:00<00:00, 24.23it/s, v_num=4, Eval BCE Loss=0.716, Eval Accuracy=0.539, Train BCE Loss=0.660, Train Accuracy=0.583]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.01it/s]
# Epoch 86: 100%|██████████| 6/6 [00:00<00:00, 50.94it/s, v_num=4, Eval BCE Loss=0.708, Eval Accuracy=0.546, Train BCE Loss=0.661, Train Accuracy=0.586]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 168.20it/s]
# Epoch 87: 100%|██████████| 6/6 [00:00<00:00, 50.71it/s, v_num=4, Eval BCE Loss=0.699, Eval Accuracy=0.542, Train BCE Loss=0.661, Train Accuracy=0.584]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 181.52it/s]
# Epoch 88: 100%|██████████| 6/6 [00:00<00:00, 51.12it/s, v_num=4, Eval BCE Loss=0.716, Eval Accuracy=0.538, Train BCE Loss=0.661, Train Accuracy=0.582]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 172.36it/s]
# Epoch 89: 100%|██████████| 6/6 [00:00<00:00, 51.35it/s, v_num=4, Eval BCE Loss=0.704, Eval Accuracy=0.551, Train BCE Loss=0.661, Train Accuracy=0.585]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 151.33it/s]
# Epoch 90: 100%|██████████| 6/6 [00:00<00:00, 51.03it/s, v_num=4, Eval BCE Loss=0.719, Eval Accuracy=0.543, Train BCE Loss=0.660, Train Accuracy=0.588]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 173.28it/s]
# Epoch 91: 100%|██████████| 6/6 [00:00<00:00, 24.16it/s, v_num=4, Eval BCE Loss=0.710, Eval Accuracy=0.543, Train BCE Loss=0.661, Train Accuracy=0.590]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 162.42it/s]
# Epoch 92: 100%|██████████| 6/6 [00:00<00:00, 50.61it/s, v_num=4, Eval BCE Loss=0.704, Eval Accuracy=0.544, Train BCE Loss=0.662, Train Accuracy=0.590]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 178.00it/s]
# Epoch 93: 100%|██████████| 6/6 [00:00<00:00, 49.90it/s, v_num=4, Eval BCE Loss=0.716, Eval Accuracy=0.538, Train BCE Loss=0.661, Train Accuracy=0.589]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.53it/s]
# Epoch 94: 100%|██████████| 6/6 [00:00<00:00, 52.02it/s, v_num=4, Eval BCE Loss=0.715, Eval Accuracy=0.536, Train BCE Loss=0.661, Train Accuracy=0.587]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 173.89it/s]
# Epoch 95: 100%|██████████| 6/6 [00:00<00:00, 50.19it/s, v_num=4, Eval BCE Loss=0.720, Eval Accuracy=0.540, Train BCE Loss=0.660, Train Accuracy=0.591]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.42it/s]
# Epoch 96: 100%|██████████| 6/6 [00:00<00:00, 50.63it/s, v_num=4, Eval BCE Loss=0.712, Eval Accuracy=0.539, Train BCE Loss=0.662, Train Accuracy=0.589]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 169.78it/s]
# Epoch 97: 100%|██████████| 6/6 [00:00<00:00, 22.72it/s, v_num=4, Eval BCE Loss=0.712, Eval Accuracy=0.536, Train BCE Loss=0.661, Train Accuracy=0.588]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 155.71it/s]
# Epoch 98: 100%|██████████| 6/6 [00:00<00:00, 50.26it/s, v_num=4, Eval BCE Loss=0.724, Eval Accuracy=0.530, Train BCE Loss=0.660, Train Accuracy=0.588]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 166.94it/s]
# Epoch 99: 100%|██████████| 6/6 [00:00<00:00, 49.05it/s, v_num=4, Eval BCE Loss=0.712, Eval Accuracy=0.533, Train BCE Loss=0.660, Train Accuracy=0.583]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 156.62it/s]
# Epoch 99: 100%|██████████| 6/6 [00:00<00:00, 40.71it/s, v_num=4, Eval BCE Loss=0.710, Eval Accuracy=0.536, Train BCE Loss=0.660, Train Accuracy=0.590]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# Epoch 99: 100%|██████████| 6/6 [00:00<00:00, 38.78it/s, v_num=4, Eval BCE Loss=0.710, Eval Accuracy=0.536, Train BCE Loss=0.660, Train Accuracy=0.590]

# %% [markdown]
# ### 🎯 Check Precision

# %% [markdown]
# Results show that EnergyDiff trained with the hyperparameters specified in `energydiff_tutorial.ipynb` has similar MIA results with Faraday with 150 and 1500 GMM Clusters.

# %%
df_mia_results_df = mia.get_mia_predictions(mia_model_df,
                                                     dm_mia_df)
mia.print_mia_results(df_mia_results_df)
# Out:
# Segment: Precision: 0.48 +/- 0.06,
# F1: 0.48, Acc: 0.65,
# True Positives: 48,
# False Positive: 52,
# Total N: 300,
# Total Positive: 100,
# Random Precision : 0.33,

# %% [markdown]
# #### Check MIA attack outlier distribution

# %%
dfseen = dm_mia_df.attack_dataset.df.query("type=='seen'")
dfunseen_same = dm_mia_df.attack_dataset.df.query("type=='unseen_same'")
dfunseen_diff = dm_mia_df.attack_dataset.df.query("type=='unseen_diff'")
assert len(dfseen) == len(dfunseen_same) == len(dfunseen_diff) == 100

# %%
seen_tensor = np.array(dfseen["tensors"].tolist())
unseen_same_tensor = np.array(dfunseen_same["tensors"].tolist())
unseen_diff_tensor = np.array(dfunseen_diff["tensors"].tolist())

tsne_input = np.concatenate([seen_tensor, unseen_same_tensor, unseen_diff_tensor])

from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
tsne_output = tsne.fit_transform(tsne_input)

# %%
plt.scatter(tsne_output[:100, 0], tsne_output[:100, 1], label="Seen")
plt.scatter(tsne_output[100:200, 0], tsne_output[100:200, 1], label="Unseen (Same)")
plt.scatter(tsne_output[200:, 0], tsne_output[200:, 1], label="Unseen (Diff)")
plt.legend()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(seen_tensor)

seen_pca = pca.transform(seen_tensor)
unseen_same_pca = pca.transform(unseen_same_tensor)
unseen_diff_pca = pca.transform(unseen_diff_tensor)

plt.scatter(seen_pca[:, 0], seen_pca[:, 1], label="Seen")
plt.scatter(unseen_same_pca[:, 0], unseen_same_pca[:, 1], label="Unseen (Same)")
plt.scatter(unseen_diff_pca[:, 0], unseen_diff_pca[:, 1], label="Unseen (Diff)")
plt.legend()
